# %%
#required library

import pandas as pd 
import requests
from bs4 import BeautifulSoup

# %%
#define the base url needed to create the file url
base_url = r"https://www.sec.gov"

#convert a normal url to a document url 
normal_url = r"https://www.sec.gov/Archives/edgar/data/1265107/0001265107-19-000004.txt"
normal_url = normal_url.replace('-','').replace('.txt','/index.json')

# define a url that leads to a 10k document landing page
documents_url = r"https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/index.json"

#request the url and decode it
headers = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/101.0.4951.67 Safari/537.36'}
content = requests.get(documents_url, headers=headers).json()

for file in content['directory']['item']:
    
    #grab the filing summary and create a new url leading to the file so we can download it
    if file['name']=='FilingSummary.xml':
        xml_summary = base_url + content['directory']['name'] + '/' + file['name']
        
        print('-'*100)
        print('File Name: '+ file['name'])
        print('File Path: '+ xml_summary)
# Out:
# ----------------------------------------------------------------------------------------------------
# File Name: FilingSummary.xml
# File Path: https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/FilingSummary.xml

# %%
#define a new base url that represents the filing folder. This will come in handy when we will download the reports.
base_url = xml_summary.replace('FilingSummary.xml','')

#request and parse the content
headers = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/101.0.4951.67 Safari/537.36'}
content = requests.get(xml_summary, headers=headers).content
soup = BeautifulSoup(content, 'lxml')

#find the 'myreports' tag becasue this contains all the individual reports submitted
reports = soup.find('myreports')

# I want a list to store all the individual components of the report, so create the master list.
master_reports = []

# loop through each report in the 'myreports' tag but avoid the last one as this will cause an error.
for report in reports.find_all('report')[:-1]:

    # let's create a dictionary to store all the different parts we need.
    report_dict = {}
    report_dict['name_short'] = report.shortname.text
    report_dict['name_long'] = report.longname.text
    report_dict['position'] = report.position.text
    report_dict['category'] = report.menucategory.text
    report_dict['url'] = base_url + report.htmlfilename.text
    
    # append the dictionary to the master list.
    master_reports.append(report_dict)

    #print the info to the user
    print('-'*100)
    print(base_url+report.htmlfilename.text)
    print(report.longname.text)
    print(report.shortname.text)
    print(report.menucategory.text)
    print(report.position.text)
# Out:
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R1.htm
# 0001000 - Document - Document and Entity Information
# Document and Entity Information
# Cover
# 1
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R2.htm
# 1001000 - Statement - Consolidated Balance Sheets
# Consolidated Balance Sheets
# Statements
# 2
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R3.htm
# 1001501 - Statement - Consolidated Balance Sheets (Parenthetical)
# Consolidated Balance Sheets (Parenthetical)
# Statements
# 3
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R4.htm
# 1002000 - Statement - Consolidated Statements of Operations and Comprehensive Income (Loss)
# Consolidated Statements of Operations and Comprehensive Income (Loss)
# Statements
# 4
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R5.htm
# 1003000 - Statement - Consolidated Statements of Cash Flows
# Consolidated Statements of Cash Flows
# Statements
# 5
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R6.htm
# 1004000 - Statement - Consolidated Statements of Stockholder's (Deficit) Equity
# Consolidated Statements of Stockholder's (Deficit) Equity
# Statements
# 6
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R7.htm
# 2101100 - Disclosure - Basis of Presentation
# Basis of Presentation
# Notes
# 7
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R8.htm
# 2102100 - Disclosure - Going Concern
# Going Concern
# Notes
# 8
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R9.htm
# 2103100 - Disclosure - Summary of Significant Accounting Policies
# Summary of Significant Accounting Policies
# Notes
# 9
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R10.htm
# 2104100 - Disclosure - Recent Accounting Pronouncements
# Recent Accounting Pronouncements
# Notes
# 10
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R11.htm
# 2105100 - Disclosure - Revenue Recognition
# Revenue Recognition
# Notes
# 11
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R12.htm
# 2106100 - Disclosure - Property and Equipment
# Property and Equipment
# Notes
# 12
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R13.htm
# 2107100 - Disclosure - Goodwill
# Goodwill
# Notes
# 13
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R14.htm
# 2108100 - Disclosure - Other Accrued Liabilities
# Other Accrued Liabilities
# Notes
# 14
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R15.htm
# 2109100 - Disclosure - Long-Term Debt
# Long-Term Debt
# Notes
# 15
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R16.htm
# 2110100 - Disclosure - Derivatives
# Derivatives
# Notes
# 16
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R17.htm
# 2111100 - Disclosure - Fair Value Measurements
# Fair Value Measurements
# Notes
# 17
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R18.htm
# 2112100 - Disclosure - Income Taxes
# Income Taxes
# Notes
# 18
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R19.htm
# 2113100 - Disclosure - Stock-based and Long-Term Compensation
# Stock-based and Long-Term Compensation
# Notes
# 19
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R20.htm
# 2114100 - Disclosure - Stockholder's Equity
# Stockholder's Equity
# Notes
# 20
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R21.htm
# 2115100 - Disclosure - Employee Benefit Plans
# Employee Benefit Plans
# Notes
# 21
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R22.htm
# 2116100 - Disclosure - Commitments, Contingencies and Other Liabilities
# Commitments, Contingencies and Other Liabilities
# Notes
# 22
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R23.htm
# 2117100 - Disclosure - Quarterly Financial Information (Unaudited - see accompanying accountants' report)
# Quarterly Financial Information (Unaudited - see accompanying accountants' report)
# Notes
# 23
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R24.htm
# 2118100 - Disclosure - Consolidating Guarantor Financial Information
# Consolidating Guarantor Financial Information
# Notes
# 24
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R25.htm
# 2119100 - Disclosure - Subsequent Events
# Subsequent Events
# Notes
# 25
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R26.htm
# 2203201 - Disclosure - Summary of Significant Accounting Policies (Policies)
# Summary of Significant Accounting Policies (Policies)
# Policies
# 26
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R27.htm
# 2303302 - Disclosure - Summary of Significant Accounting Policies (Tables)
# Summary of Significant Accounting Policies (Tables)
# Tables
# 27
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R28.htm
# 2305301 - Disclosure - Revenue Recognition (Tables)
# Revenue Recognition (Tables)
# Tables
# 28
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R29.htm
# 2306301 - Disclosure - Property and Equipment (Tables)
# Property and Equipment (Tables)
# Tables
# 29
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R30.htm
# 2307301 - Disclosure - Goodwill (Tables)
# Goodwill (Tables)
# Tables
# 30
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R31.htm
# 2308301 - Disclosure - Other Accrued Liabilities (Tables)
# Other Accrued Liabilities (Tables)
# Tables
# 31
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R32.htm
# 2309301 - Disclosure - Long-Term Debt (Tables)
# Long-Term Debt (Tables)
# Tables
# 32
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R33.htm
# 2310301 - Disclosure - Derivatives (Tables)
# Derivatives (Tables)
# Tables
# 33
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R34.htm
# 2311301 - Disclosure - Fair Value Measurements (Tables)
# Fair Value Measurements (Tables)
# Tables
# 34
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R35.htm
# 2312301 - Disclosure - Income Taxes (Tables)
# Income Taxes (Tables)
# Tables
# 35
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R36.htm
# 2313301 - Disclosure - Stock-based and Long-Term Compensation (Tables)
# Stock-based and Long-Term Compensation (Tables)
# Tables
# 36
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R37.htm
# 2314301 - Disclosure - Stockholder's Equity (Tables)
# Stockholder's Equity (Tables)
# Tables
# 37
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R38.htm
# 2316301 - Disclosure - Commitments, Contingencies and Other Liabilities (Tables)
# Commitments, Contingencies and Other Liabilities (Tables)
# Tables
# 38
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R39.htm
# 2317301 - Disclosure - Quarterly Financial Information (Unaudited - see accompanying accountants' report)) (Tables)
# Quarterly Financial Information (Unaudited - see accompanying accountants' report)) (Tables)
# Tables
# 39
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R40.htm
# 2318301 - Disclosure - Consolidating Guarantor Financial Information (Tables)
# Consolidating Guarantor Financial Information (Tables)
# Tables
# 40
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R41.htm
# 2401401 - Disclosure - Basis of Presentation - Narrative (Details)
# Basis of Presentation - Narrative (Details)
# Details
# 41
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R42.htm
# 2402401 - Disclosure - Going Concern - Narrative (Details)
# Going Concern - Narrative (Details)
# Details
# 42
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R43.htm
# 2403403 - Disclosure - Summary of Significant Accounting Policies - Narrative (Details)
# Summary of Significant Accounting Policies - Narrative (Details)
# Details
# 43
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R44.htm
# 2403404 - Disclosure - Summary of Significant Accounting Policies - Roll Forward of Receivable Allowance (Details)
# Summary of Significant Accounting Policies - Roll Forward of Receivable Allowance (Details)
# Details
# 44
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R45.htm
# 2403405 - Disclosure - Summary of Significant Accounting Policies - Property Plant and Equipment Useful Life (Details)
# Summary of Significant Accounting Policies - Property Plant and Equipment Useful Life (Details)
# Details
# 45
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R46.htm
# 2403406 - Disclosure - Summary of Significant Accounting Policies - Expected Subscriber Fees (Details)
# Summary of Significant Accounting Policies - Expected Subscriber Fees (Details)
# Details
# 46
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R47.htm
# 2405402 - Disclosure - Revenue Recognition - Disaggregated Revenue by Source (Details)
# Revenue Recognition - Disaggregated Revenue by Source (Details)
# Details
# 47
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R48.htm
# 2405403 - Disclosure - Revenue Recognition - Contract Balances (Details)
# Revenue Recognition - Contract Balances (Details)
# Details
# 48
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R49.htm
# 2405404 - Disclosure - Revenue Recognition - Impact on Condensed Consolidated Balance Sheets (Details)
# Revenue Recognition - Impact on Condensed Consolidated Balance Sheets (Details)
# Details
# 49
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R50.htm
# 2405405 - Disclosure - Revenue Recognition - Impact on Condensed Consolidated Statements of Operations and Comprehensive Income (Loss) (Details)
# Revenue Recognition - Impact on Condensed Consolidated Statements of Operations and Comprehensive Income (Loss) (Details)
# Details
# 50
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R51.htm
# 2405406 - Disclosure - Revenue Recognition - Impact on Condensed Consolidated Statement of Cash Flows (Details)
# Revenue Recognition - Impact on Condensed Consolidated Statement of Cash Flows (Details)
# Details
# 51
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R52.htm
# 2406402 - Disclosure - Property and Equipment - Schedule of Property and Equipment (Details)
# Property and Equipment - Schedule of Property and Equipment (Details)
# Details
# 52
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R53.htm
# 2406403 - Disclosure - Property and Equipment - Narrative (Details)
# Property and Equipment - Narrative (Details)
# Details
# 53
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R54.htm
# 2407402 - Disclosure - Goodwill - Schedule of Goodwill (Details)
# Goodwill - Schedule of Goodwill (Details)
# Details
# 54
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R55.htm
# 2407403 - Disclosure - Goodwill - Narrative (Details)
# Goodwill - Narrative (Details)
# Details
# 55
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R56.htm
# 2408402 - Disclosure - Other Accrued Liabilities - Schedule of other accrued liabilities (Details)
# Other Accrued Liabilities - Schedule of other accrued liabilities (Details)
# Details
# 56
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R57.htm
# 2409402 - Disclosure - Long-Term Debt - Schedule of Long Term Debt (Details)
# Long-Term Debt - Schedule of Long Term Debt (Details)
# Details
# 57
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R58.htm
# 2409403 - Disclosure - Long-Term Debt - Narrative (Details)
# Long-Term Debt - Narrative (Details)
# Details
# 58
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R59.htm
# 2409404 - Disclosure - Long-Term Debt - Schedule of Long Term Debt Maturity (Details)
# Long-Term Debt - Schedule of Long Term Debt Maturity (Details)
# Details
# 59
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R60.htm
# 2410402 - Disclosure - Derivatives - Narrative (Details)
# Derivatives - Narrative (Details)
# Details
# 60
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R61.htm
# 2410403 - Disclosure - Derivatives - Summary of Outstanding Swaps (Details)
# Derivatives - Summary of Outstanding Swaps (Details)
# Details
# 61
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R62.htm
# 2410404 - Disclosure - Derivatives - Summary of Derivatives Designated as Cash Flow Hedges (Details)
# Derivatives - Summary of Derivatives Designated as Cash Flow Hedges (Details)
# Details
# 62
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R63.htm
# 2411402 - Disclosure - Fair Value Measurements - Schedule of Fair Value Measured On Recurring Basis (Details)
# Fair Value Measurements - Schedule of Fair Value Measured On Recurring Basis (Details)
# Details
# 63
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R64.htm
# 2411403 - Disclosure - Fair Value Measurements - Schedule of Instruments Not Carried at Fair Value (Details)
# Fair Value Measurements - Schedule of Instruments Not Carried at Fair Value (Details)
# Details
# 64
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R65.htm
# 2412402 - Disclosure - Income Taxes - Schedule of Components of Income Tax (Details)
# Income Taxes - Schedule of Components of Income Tax (Details)
# Details
# 65
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R66.htm
# 2412403 - Disclosure - Income Taxes - Schedule of Effective Income Tax Reconciliation (Details)
# Income Taxes - Schedule of Effective Income Tax Reconciliation (Details)
# Details
# 66
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R67.htm
# 2412404 - Disclosure - Income Taxes - Schedule of Deferred Tax Assets and Liabilities (Details)
# Income Taxes - Schedule of Deferred Tax Assets and Liabilities (Details)
# Details
# 67
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R68.htm
# 2412405 - Disclosure - Income Taxes - Narrative (Details)
# Income Taxes - Narrative (Details)
# Details
# 68
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R69.htm
# 2412406 - Disclosure - Income Taxes - Schedule of Unrecognized Tax Benefit Roll-Forward (Details)
# Income Taxes - Schedule of Unrecognized Tax Benefit Roll-Forward (Details)
# Details
# 69
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R70.htm
# 2413402 - Disclosure - Stock-based and Long-Term Compensation - Narrative (Details)
# Stock-based and Long-Term Compensation - Narrative (Details)
# Details
# 70
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R71.htm
# 2413403 - Disclosure - Stock-based and Long-Term Compensation - Schedule of Option Activity (Details)
# Stock-based and Long-Term Compensation - Schedule of Option Activity (Details)
# Details
# 71
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R72.htm
# 2413404 - Disclosure - Stock-based and Long-Term Compensation - Schedule of Unvested Restricted Stock Awards and Restricted Stock Units (Details)
# Stock-based and Long-Term Compensation - Schedule of Unvested Restricted Stock Awards and Restricted Stock Units (Details)
# Details
# 72
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R73.htm
# 2414402 - Disclosure - Stockholder's Equity - Narrative (Details)
# Stockholder's Equity - Narrative (Details)
# Details
# 73
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R74.htm
# 2414403 - Disclosure - Stockholder's Equity - Roll Forward Activity (Details)
# Stockholder's Equity - Roll Forward Activity (Details)
# Details
# 74
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R75.htm
# 2415401 - Disclosure - Employee Benefit Plans - Narrative (Details)
# Employee Benefit Plans - Narrative (Details)
# Details
# 75
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R76.htm
# 2416402 - Disclosure - Commitments, Contingencies and Other Liabilities - Summary of Future Minimum Lease Payments (Details)
# Commitments, Contingencies and Other Liabilities - Summary of Future Minimum Lease Payments (Details)
# Details
# 76
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R77.htm
# 2416403 - Disclosure - Commitments, Contingencies and Other Liabilities - Narrative (Details)
# Commitments, Contingencies and Other Liabilities - Narrative (Details)
# Details
# 77
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R78.htm
# 2417402 - Disclosure - Quarterly Financial Information (Unaudited - see accompanying accountants' report) (Details)
# Quarterly Financial Information (Unaudited - see accompanying accountants' report) (Details)
# Details
# 78
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R79.htm
# 2418402 - Disclosure - Condensed Consolidating Balance Sheet (Details)
# Condensed Consolidating Balance Sheet (Details)
# Details
# 79
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R80.htm
# 2418403 - Disclosure - Condensed Consolidating Statement of Operations and Comprehensive Income (Loss) (Details)
# Condensed Consolidating Statement of Operations and Comprehensive Income (Loss) (Details)
# Details
# 80
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R81.htm
# 2418404 - Disclosure - Condensed Consolidating Statements of Cash Flows (Details)
# Condensed Consolidating Statements of Cash Flows (Details)
# Details
# 81
# ----------------------------------------------------------------------------------------------------
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R9999.htm
# Uncategorized Items - mtii-20181231.xml
# Uncategorized Items - mtii-20181231.xml
# Cover
# 82

# %%
#create the list to hold the statements url 
statements_url=[]

for report_dict in master_reports:
    
    #define the statements we want to look for 
    item_1 = r"Consolidated Balance Sheets"
    item_2 = r"Consolidated Statements of Operations and Comprehensive Income (Loss)"
    item_3 = r"Consolidated Statements of Cash Flows"
    item_4 = r"Consolidated Statements of Stockholder's (Deficit) Equity"
    
    #store the item in a list
    report_list = [item_1, item_2, item_3, item_4]
    
    #if the short name can be found in the report list
    if report_dict['name_short'] in report_list:
        
        #print some info and store it in the statements_url
        print('-'*100)
        print(report_dict['name_short'])
        print(report_dict['url'])
        
        statements_url.append(report_dict['url'])
# Out:
# ----------------------------------------------------------------------------------------------------
# Consolidated Balance Sheets
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R2.htm
# ----------------------------------------------------------------------------------------------------
# Consolidated Statements of Operations and Comprehensive Income (Loss)
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R4.htm
# ----------------------------------------------------------------------------------------------------
# Consolidated Statements of Cash Flows
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R5.htm
# ----------------------------------------------------------------------------------------------------
# Consolidated Statements of Stockholder's (Deficit) Equity
# https://www.sec.gov/Archives/edgar/data/1265107/000126510719000004/R6.htm

# %%
#let's assume we want all the statements in a single data set
statements_data = []

#loop through each statements url
for statement in statements_url:
    
    #define a dictionary that will store the different parts of the statement
    statement_data = {}
    statement_data['headers'] = []
    statement_data['sections'] = []
    statement_data['data'] = []
    
    # request the statement file content
    headers = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/101.0.4951.67 Safari/537.36'}
    content = requests.get(statement, headers=headers).content
    report_soup = BeautifulSoup(content, 'html')

    # find all the rows, figure out what type of row it is, parse the elements, and store in the statement file list.
    for index, row in enumerate(report_soup.table.find_all('tr')):
        
        # first let's get all the elements.
        cols = row.find_all('td')
        
        # if it's a regular row and not a section or a table header
        if (len(row.find_all('th')) == 0 and len(row.find_all('strong')) == 0): 
            reg_row = [ele.text.strip() for ele in cols]
            statement_data['data'].append(reg_row)
            
        # if it's a regular row and a section but not a table header
        elif (len(row.find_all('th')) == 0 and len(row.find_all('strong')) != 0):
            sec_row = cols[0].text.strip()
            statement_data['sections'].append(sec_row)
            
        # finally if it's not any of those it must be a header
        elif (len(row.find_all('th')) != 0):            
            hed_row = [ele.text.strip() for ele in row.find_all('th')]
            statement_data['headers'].append(hed_row)
            
        else:            
            print('We encountered an error.')

    # append it to the master list.
    statements_data.append(statement_data)

# %%
# Grab the proper components
income_header =  statements_data[1]['headers'][1]
income_data = statements_data[1]['data']

# Put the data in a DataFrame
income_df = pd.DataFrame(income_data)

# Display
print('-'*100)
print('Before Reindexing')
print('-'*100)
display(income_df.head())

# Define the Index column, rename it, and we need to make sure to drop the old column once we reindex.
income_df.index = income_df[0]
income_df.index.name = 'Category'
income_df = income_df.drop(0, axis = 1)

# Display
print('-'*100)
print('Before Regex')
print('-'*100)
display(income_df.head())

# Get rid of the '$', '(', ')', and convert the '' to NaNs.
income_df = income_df.replace('[\$,)]','', regex=True )\
                     .replace( '[(]','-', regex=True)\
                     .replace( '', 'NaN', regex=True)

# Display
print('-'*100)
print('Before type conversion')
print('-'*100)
display(income_df.head())

# everything is a string, so let's convert all the data to a float.
income_df = income_df.astype(float)

# Change the column headers
income_df.columns = income_header

# Display
print('-'*100)
print('Final Product')
print('-'*100)

# show the df
income_df

# drop the data in a CSV file if need be.
income_df.to_csv('income_state.csv')
# Out:
# ----------------------------------------------------------------------------------------------------
# Before Reindexing
# ----------------------------------------------------------------------------------------------------
#                                                   0          1          2   \
# 0                                        Net revenue  $ 134,436  $ 137,156
# 1                                   Cost of services
# 2  Selling, general and administrative, including...
# 3                             Radio conversion costs
# 4  Amortization of subscriber accounts, deferred ...
#
#           3          4          5          6          7          8   \
# 0  $ 135,013  $ 133,753  $ 133,546  $ 138,211  $ 140,498  $ 141,200
# 1
# 2
# 3
# 4
#
#           9          10         11
# 0  $ 540,358  $ 553,455  $ 570,372
# 1    128,939    119,193    115,236
# 2    118,940    155,902    114,152
# 3          0        450     18,422
# 4    211,639    236,788    246,753
# ----------------------------------------------------------------------------------------------------
# Before Regex
# ----------------------------------------------------------------------------------------------------
#                                                            1          2   \
# Category
# Net revenue                                         $ 134,436  $ 137,156
# Cost of services
# Selling, general and administrative, including ...
# Radio conversion costs
# Amortization of subscriber accounts, deferred c...
#
#                                                            3          4   \
# Category
# Net revenue                                         $ 135,013  $ 133,753
# Cost of services
# Selling, general and administrative, including ...
# Radio conversion costs
# Amortization of subscriber accounts, deferred c...
#
#                                                            5          6   \
# Category
# Net revenue                                         $ 133,546  $ 138,211
# Cost of services
# Selling, general and administrative, including ...
# Radio conversion costs
# Amortization of subscriber accounts, deferred c...
#
#                                                            7          8   \
# Category
# Net revenue                                         $ 140,498  $ 141,200
# Cost of services
# Selling, general and administrative, including ...
# Radio conversion costs
# Amortization of subscriber accounts, deferred c...
#
#                                                            9          10  \
# Category
# Net revenue                                         $ 540,358  $ 553,455
# Cost of services                                      128,939    119,193
# Selling, general and administrative, including ...    118,940    155,902
# Radio conversion costs                                      0        450
# Amortization of subscriber accounts, deferred c...    211,639    236,788
#
#                                                            11
# Category
# Net revenue                                         $ 570,372
# Cost of services                                      115,236
# Selling, general and administrative, including ...    114,152
# Radio conversion costs                                 18,422
# Amortization of subscriber accounts, deferred c...    246,753
# ----------------------------------------------------------------------------------------------------
# Before type conversion
# ----------------------------------------------------------------------------------------------------
#                                                          1        2        3   \
# Category
# Net revenue                                          134436   137156   135013
# Cost of services                                        NaN      NaN      NaN
# Selling, general and administrative, including ...      NaN      NaN      NaN
# Radio conversion costs                                  NaN      NaN      NaN
# Amortization of subscriber accounts, deferred c...      NaN      NaN      NaN
#
#                                                          4        5        6   \
# Category
# Net revenue                                          133753   133546   138211
# Cost of services                                        NaN      NaN      NaN
# Selling, general and administrative, including ...      NaN      NaN      NaN
# Radio conversion costs                                  NaN      NaN      NaN
# Amortization of subscriber accounts, deferred c...      NaN      NaN      NaN
#
#                                                          7        8        9   \
# Category
# Net revenue                                          140498   141200   540358
# Cost of services                                        NaN      NaN   128939
# Selling, general and administrative, including ...      NaN      NaN   118940
# Radio conversion costs                                  NaN      NaN        0
# Amortization of subscriber accounts, deferred c...      NaN      NaN   211639
#
#                                                          10       11
# Category
# Net revenue                                          553455   570372
# Cost of services                                     119193   115236
# Selling, general and administrative, including ...   155902   114152
# Radio conversion costs                                  450    18422
# Amortization of subscriber accounts, deferred c...   236788   246753
# ----------------------------------------------------------------------------------------------------
# Final Product
# ----------------------------------------------------------------------------------------------------
